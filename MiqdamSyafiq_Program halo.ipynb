# %%
print("Program halo.py")
print("by syafiqmiqdam16@mail.ugm.ac.id")
# Out:
# Program halo.py
# by syafiqmiqdam16@mail.ugm.ac.id

# %%
print("#|================================|")
print("#|                 |")
print("#| Program halo.py |")
print("#| by syafiqmiqdam16@mail.ugm.ac.id|")
print("#|                 |")
print("#|================================|")
# Out:
# #|================================|
# #|                 |
# #| Program halo.py |
# #| by syafiqmiqdam16@mail.ugm.ac.id|
# #|                 |
# #|================================|
